# %% [markdown]
# # Public API V2 <a class="anchor" id="notebook-head"></a>

# %% [markdown]
# # Введение <a class="anchor" id="intro"></a>
#
# В этом руководстве показано, как использовать **Public API** сервиса [Distributed Train](https://console.cloud.ru/spa/mlspace/profile/review) для автоматизации работы с данными, Jupyter Server и задачами (Jobs).
#
# С помощью API можно выполнять действия, которые обычно выполняются через [интерфейс Distributed Train](https://cloud.ru/ru/docs/aicloud/mlspace/concepts/quickstart.html):
# создавать и управлять Jupter server, переносить данные между хранилищами, запускать и управлять задачами обучения.
#
# ---
#
# ### Вы будете использовать следующие сервисы
#
# - **[Distributed Train](https://cloud.ru/docs/aicloud/mlspace/index)** — сервис для распределенного обучения ML-моделей и совместной работы DS-команд.
# - **[Object Storage](https://cloud.ru/docs/s3e/ug/index)** — объектное S3-хранилище.
#
# ---
#
# ### Документация
#
# - **Справочник API** — [Public API V2](https://cloud.ru/docs/aicloud/mlspace/concepts/api)
# - **Актуальная спецификация (автодокументация по методам)** — [Redoc](https://api.ai.cloud.ru/public/v2/redoc)
# - **Публичный Swagger** — [Swagger UI](https://api.ai.cloud.ru/public/v2/docs#)
#
# ---
#
# ## Перед началом работы
#
# - [Зарегистрируйтесь в личном кабинете Cloud.ru.](https://cloud.ru/docs/console/ug/topics/guides__registration)
# - Если вы уже зарегистрированы, [войдите под своей учетной записью](https://cloud.ru/docs/console/ug/topics/guides__auth).
# - Убедитесь, что вас есть доступ к **[Distributed Train](https://cloud.ru/docs/aicloud/mlspace/index)** и **[Object Storage](https://cloud.ru/docs/s3e/ug/index)**.
# - Убедитесь, что у вас создан **[workspace](https://cloud.ru/docs/aicloud/mlspace/concepts/guides/guides__profile/profile__create-ws)** в Distributed Train.
#
# ---

# %% [markdown]
# # Содержание <a class="anchor" id="toc"></a>

# %% [markdown]
# 1. [Введение](#intro)
# 2. [Установка зависимостей](#install)
# 3. [Импорт библиотек и базовые настройки](#imports)
# 4. [Ключи для работы с Distributed Train](#credentials)
#    - [Структура файла credentials_dict.json](#credentials-structure)
#    - [Загрузка ключей](#credentials-load)
# 5. [Авторизация и получение токена доступа](#auth)
# 6. [Работа с данными](#s3)
#    - [(Опционально )Создание и активация коннектора](#s3-create)
#    - [Получение списка коннекторов](#s3-get-buckets)
#    - [Создание переноса из S3 на NFS](#s3-copy-to-nfs)
#    - [Получение логов переноса](#s3-transfer-logs)
# 7. [Операции с Jupyter Serverr](#jupyter)
#    - [Создание jupyter Server](#jupyter-create)
#    - [Получение списка запущенных Jupyter Server](#jupyter-list)
#    - [Приостановка Jupyter Server)](#jupyter-pause)
#    - [Возобновление Jupyter Server)](#jupyter-resume)
#    - [Удаление Jupyter Server)](#jupyter-delete)
# 8. [Работа с задачами (Jobs)](#jobs)
#    - [Создание задачи](#jobs-create)
#    - [Получение списка задач](#jobs-list)
#    - [Проверка статуса задачи](#jobs-status)
#    - [Получение логи задачи](#jobs-logs)
#    - [Остановка задачи](#jobs-delete)

# %% [markdown]
# # Установка зависимостей ([содержание](#toc))<a class="anchor" id="install"></a>
#
# Перед началом работы убедитесь, что установлены все необходимые библиотеки.
#
# Следующая команда установит их (выполняется один раз):

# %%
# !pip install requests ipython

# %% [markdown]
# # Импорт библиотек и базовые настройки ([содержание](#toc))<a class="anchor" id="imports"></a>
#
# В этом разделе импортируем необходимые библиотеки и зададим базовые переменные,
# которые будут использоваться при выполнении всех API-запросов.
#
# - `host` — базовый адрес API.
# - `rest_call_template` — шаблон для построения полного URL при вызовах API.

# %%
import json
import requests
from IPython.display import JSON

# %%
host = "https://api.ai.cloud.ru"

rest_call_template = "{}/public/v2/{}"

# %% [markdown]
# # Ключи для работы с Distributed Train ([содержание](#toc))<a class="anchor" id="credentials"></a>

# %% [markdown]
# ## Структура файла credentials_dict.json ([содержание](#toc))<a class="anchor" id="credentials-structure"></a>
#
# Для работы с API Distributed Train вам понадобятся несколько ключей и идентификаторов.
# Подробнее см. в [документации](https://cloud.ru/docs/aicloud/mlspace/concepts/guides/guides__profile/profile__develop-func).
#
# Нам потребуются следующие данные:
#
# - **Long API Keys (Client ID и Client Secret)** — персональные ключи для авторизации в сервисе.
#   Получить их можно в [профиле пользователя в личном кабинете](https://cloud.ru/docs/console_api/ug/topics/guides__api_key).
# - **x-workspace-id** — уникальный идентификатор вашего воркспейса. Он индивидуален для каждого созданного воркспейса.
# - **x-api-key** — клиентский ключ доступа к API. Тоже индивидуален для каждого воркспейса.
# - **namespace** — пространство имен воркспейса в Distributed Train.
#
# Чтобы узнать `namespace`, откройте терминал Jupyter Server и выполните команду:
#
# ```bash
# env | grep NAMESPACE
# ```

# %% [markdown]
# Заполните файл credentials_dict.json.
#
# Структура файла:
#
# ```json
# {
#   "client_id": "ваш client_id",
#   "client_secret": "ваш client_secret",
#   "workspaces": [
#     {
#       "name": "имя воркспейса", # опционально
#       "namespace": "ваш namespace",
#       "id": "ваш x-workspace-id",
#       "x-api-key": "ваш x-api-key"
#     }
#   ]
# }
# ```

# %% [markdown]
# ## Загрузка ключей  ([содержание](#toc))<a class="anchor" id="credentials-load"></a>
#
# Загружаем ключи из `credentials_dict.json` и формируем словарь `credentials` с `client_id` и `client_secret` для авторизации.

# %%
with open("credentials_dict.json", "r") as f:
    credentials_dict = json.load(f)

credentials = {
    "client_id": credentials_dict["client_id"],
    "client_secret": credentials_dict["client_secret"],
}

# %% [markdown]
# # Авторизация ([содержание](#toc))<a class="anchor" id="auth"></a>

# %%
endpoint = "service_auth"

json_body = json.dumps(credentials)

headers = {
    "x-api-key": credentials_dict["workspaces"][0]["x-api-key"],
    "Content-Type": "application/json",
}

url = rest_call_template.format(host, endpoint)
url
response = requests.request("POST", url, headers=headers, data=json_body)

auth_response_json = json.loads(response.text)

JSON(auth_response_json)

# %% [markdown]
# # Работа с данными ([содержание](#toc))<a class="anchor" id="s3"></a>
#
# В этом разделе мы будем работать с данными через Public API V2.
#
# Для выполнения примеров вам понадобится **бакет в сервисе [Evolution Object Storage](https://cloud.ru/docs/s3e/ug/topics/guides__bucket-create?source-platform=Evolution)**.
#  После создания бакет будет доступен в качестве коннектора с типом `s3evolution`.
#
# Если вы хотите использовать **сторонний бакет**, необходимо будет создать коннектор.

# %% [markdown]
# ## (Опционально) Создание и активация коннектора  ([содержание](#toc))<a class="anchor" id="s3-create"></a>
# Выполните эти шаги, если используете сторонний S3 бакет
#
# Для создания коннектора потребуются следующие параметры:
#
# - `s3_endpoint` — Endpoint сервиса S3.
# - `s3_bucket_name` — Имя бакета.
# - `s3_access_key_id` — Access Key ID.
# - `s3_security_key` — Secret Access Key.

# %%
s3_endpoint = ""
s3_bucket_name = ""
s3_access_key_id = ""
s3_security_key = ""

# %%
endpoint = "data_transfer/v3/connectors"


headers = {
    "x-api-key": credentials_dict["workspaces"][0]["x-api-key"],
    "authorization": auth_response_json["token"]["access_token"],
    "x-workspace-id": credentials_dict["workspaces"][0]["id"],
}

json_body = {
    "name": "api-test",
    "source_type": "s3custom",
    "workspace_id": credentials_dict["workspaces"][0]["id"],
    "favorite": False,
    "parameters": {
        "endpoint": s3_endpoint,
        "bucket": s3_bucket_name,
        "access_key_id": s3_access_key_id,
        "security_key": s3_security_key,
    },
}

url = rest_call_template.format(host, endpoint)

response = requests.request("POST", url, headers=headers, json=json_body)

job_response_json = json.loads(response.text)

JSON(job_response_json)

# %% [markdown]
# ### Проверяем работу коннектора

# %%
s3_connector_id = job_response_json["connector_id"]

# %%
endpoint = f"data_transfer/v3/connectors/s3custom/{s3_connector_id}/try"


headers = {
    "x-api-key": credentials_dict["workspaces"][0]["x-api-key"],
    "authorization": auth_response_json["token"]["access_token"],
    "x-workspace-id": credentials_dict["workspaces"][0]["id"],
}


url = rest_call_template.format(host, endpoint)

response = requests.request("POST", url, headers=headers)

job_response_json = json.loads(response.text)

JSON(job_response_json)

# %% [markdown]
# ## Получение списка коннекторов ([содержание](#toc))<a class="anchor" id="s3-get-buckets"></a>

# %%
endpoint = "data_transfer/v3/connectors"


headers = {
    "x-api-key": credentials_dict["workspaces"][0]["x-api-key"],
    "authorization": auth_response_json["token"]["access_token"],
    "x-workspace-id": credentials_dict["workspaces"][0]["id"],
}


url = rest_call_template.format(host, endpoint)

response = requests.request("GET", url, headers=headers)

job_response_json = json.loads(response.text)

JSON(job_response_json)

# %% [markdown]
# ## Создание переноса из S3 на NFS ([содержание](#toc))<a class="anchor" id="s3-copy-to-nfs"></a>

# %%
endpoint = "data_transfer/v5/transfer"

headers = {
    "x-api-key": credentials_dict["workspaces"][0]["x-api-key"],
    "authorization": auth_response_json["token"]["access_token"],
    "x-workspace-id": credentials_dict["workspaces"][0]["id"],
}

json_body = {
    "cluster_name": "pd42",
    "connector_id": s3_connector_id,
    "destination_connector_id": credentials_dict["workspaces"][0]["id"],
    "name": "api-test-s3-to-nfs",
    "description": "test transfer",
    "strategy": "write_all",
    "favorite": False,
    "query": {"source": "kagglecatsanddogs_5340.zip", "destination": "api-test/"},
    "connector_type": "s3evolution",  # замените на s3custom если используете сторонний бакет
    "destination_connector_type": "nfs",
}


url = rest_call_template.format(host, endpoint)

response = requests.request("POST", url, headers=headers, json=json_body)

job_response_json = json.loads(response.text)

JSON(job_response_json)

# %% [markdown]
# ## Получение логов переноса ([содержание](#toc)) <a class="anchor" id="s3-transfer-logs"></a>

# %%
transfer_id = job_response_json["transfer_id"]

# %%
endpoint = f"data_transfer/v2/events/list?offset=0&limit=1000&transfer_id={transfer_id}"

headers = {
    "x-api-key": credentials_dict["workspaces"][0]["x-api-key"],
    "authorization": auth_response_json["token"]["access_token"],
    "x-workspace-id": credentials_dict["workspaces"][0]["id"],
}

url = rest_call_template.format(host, endpoint)

response = requests.request("GET", url, headers=headers)

job_response_json = json.loads(response.text)

JSON(job_response_json)

# %% [markdown]
# # Операции с Jupyter Server ([содержание](#toc))<a class="anchor" id="jupyter"></a>
#
# В этом разделе рассмотрим основные операции с Jupyter server:
# - создание
# - приостановку
# - возобновление
# - удаление

# %% [markdown]
# ## Создание jupyter Server ([содержание](#toc))<a class="anchor" id="jupyter-create"></a>

# %%
namespace = credentials_dict["workspaces"][0]["namespace"]

endpoint = f"notebooks/v2/{namespace}/notebook"


headers = {
    "x-api-key": credentials_dict["workspaces"][0]["x-api-key"],
    "authorization": auth_response_json["token"]["access_token"],
    "x-workspace-id": credentials_dict["workspaces"][0]["id"],
}

json_body = {
    "image": {
        "name": "cr.ai.cloud.ru/aicloud-jupyter/jupyter-server",
        "tag": "0.0.99",
        "type": "datahub",
    },
    "name": "api-test",
    "instance_type": "free.0gpu",
    "region": "SR004",
}


url = rest_call_template.format(host, endpoint)
response = requests.request("POST", url, headers=headers, json=json_body)

job_response_json = json.loads(response.text)

JSON(job_response_json)

# %% [markdown]
# ## Получение списка запущенных Jupyter Server ([содержание](#toc))<a class="anchor" id="jupyter-list"></a>

# %%
endpoint = f"notebooks/v2/notebooks"


headers = {
    "x-api-key": credentials_dict["workspaces"][0]["x-api-key"],
    "authorization": auth_response_json["token"]["access_token"],
    "x-workspace-id": credentials_dict["workspaces"][0]["id"],
}


url = rest_call_template.format(host, endpoint)
response = requests.request("GET", url, headers=headers)

job_response_json = json.loads(response.text)

JSON(job_response_json)

# %% [markdown]
# ## Приостановка Jupyter Server ([содержание](#toc))<a class="anchor" id="jupyter-pause"></a>
#
#
# #### Определение `notebook_uuid`
#
# Для выполнения дальнейших запросов API нам понадобится идентификатор ноутбука — `notebook_uuid`.
#
# Его можно получить двумя способами:
#
# 1. **Из вывода предыдущей ячейки**, где мы получали список ноутбуков.
#    Пример вывода:
#    ```python
#    {
#      'notebooks': [
#        {
#          'uid': '92afac15-e709-49b0-8320-871bba47bc89',
#          'name': 'api-test',
#          'status': 'running',
#          ...
#        }
#      ]
#    }
#     ```
#     notebook_uuid — это значение поля uid.
#
# 2. Через интерфейс Jupyter Server:
#     - Откройте список своих ноутбуков
#
#     - Нажмите на название нужного ноутбука
#     - Скопируйте ID

# %%
notebook_uuid = ""  # укажите UID вашего ноутбука

endpoint = f"notebooks/v2/notebook/{notebook_uuid}/pause"

headers = {
    "x-api-key": credentials_dict["workspaces"][0]["x-api-key"],
    "authorization": auth_response_json["token"]["access_token"],
    "x-workspace-id": credentials_dict["workspaces"][0]["id"],
}


url = rest_call_template.format(host, endpoint)
response = requests.request("POST", url, headers=headers)

job_response_json = json.loads(response.text)

JSON(job_response_json)

# %% [markdown]
# ## Возобновление Jupyter Server ([содержание](#toc))<a class="anchor" id="jupyter-resume"></a>

# %%
notebook_uuid = ""  # укажите UID вашего ноутбука

endpoint = f"notebooks/v1/{namespace}/notebook/{notebook_uuid}/resume"

headers = {
    "x-api-key": credentials_dict["workspaces"][0]["x-api-key"],
    "authorization": auth_response_json["token"]["access_token"],
    "x-workspace-id": credentials_dict["workspaces"][0]["id"],
}

json_body = {"instance_type": "free.0gpu", "region": "SR004"}

url = rest_call_template.format(host, endpoint)
response = requests.request("POST", url, headers=headers, json=json_body)

job_response_json = json.loads(response.text)

JSON(job_response_json)

# %% [markdown]
# ## Удаление Jupyter Server ([содержание](#toc))<a class="anchor" id="jupyter-delete"></a>

# %%
notebook_uuid = ""  # укажите UID вашего ноутбука

endpoint = f"notebooks/v2/notebook/{notebook_uuid}"


headers = {
    "x-api-key": credentials_dict["workspaces"][0]["x-api-key"],
    "authorization": auth_response_json["token"]["access_token"],
    "x-workspace-id": credentials_dict["workspaces"][0]["id"],
}


url = rest_call_template.format(host, endpoint)
response = requests.request("DELETE", url, headers=headers)

job_response_json = json.loads(response.text)

JSON(job_response_json)

# %% [markdown]
# # Операции с задачами обученя ([содержание](#toc))<a class="anchor" id="jobs"></a>

# %% [markdown]
# ## Запуск задачи ([содержание](#toc))<a class="anchor" id="jobs-create"></a>

# %%
endpoint = "jobs"

headers = {
    "x-api-key": credentials_dict["workspaces"][0]["x-api-key"],
    "authorization": auth_response_json["token"]["access_token"],
    "x-workspace-id": credentials_dict["workspaces"][0]["id"],
}

json_body = {
    "script": "/home/jovyan/quick-start/job_launch_cpu/xgboost-boston-house-price.py",
    "base_image": "cr.ai.cloud.ru/aicloud-base-images/cuda11.8-torch2-py39:0.0.36",
    "instance_type": "cpu.8C.32G",
    "region": "SR004",
    "type": "pytorch2",
    "n_workers": 1,
    "job_desc": "api test | cpu job",
}

url = rest_call_template.format(host, endpoint)

response = requests.request("POST", url, headers=headers, json=json_body)

job_response_json = json.loads(response.text)

JSON(job_response_json)

# %% [markdown]
# Сохраним job_name, чтобы использовать его для дальнейших операций с задачей.

# %%
job_name = job_response_json["job_name"]

# %% [markdown]
# ## Получение списка задач ([содержание](#toc))<a class="anchor" id="jobs-list"></a>

# %%
endpoint = "jobs"

headers = {
    "x-api-key": credentials_dict["workspaces"][0]["x-api-key"],
    "authorization": auth_response_json["token"]["access_token"],
    "x-workspace-id": credentials_dict["workspaces"][0]["id"],
}

url = rest_call_template.format(host, endpoint)

response = requests.request("GET", url, headers=headers)

jobs_response_json = json.loads(response.text)

JSON(jobs_response_json)

# %% [markdown]
# ## Проверка статуса задачи ([содержание](#toc))<a class="anchor" id="jobs-status"></a>

# %% [markdown]
# ### Для задач обучения существуют следующие статусы:
#
# - `Pending` — задача обучения находится в очереди на запуск.
#
# - `Running` — задача обучения запущена.
#
# - `Completed` — успешно завершено для обучения на GPU.
#
# - `Deleted` — задача удалена.
#
# - `Failed` — ошибка в процессе запуска, обучения или в скрипте.
#
# - `Stopped` — остановлена пользователем.
#
# - `Succeeded` — успешно завершено для обучения на CPU.
#
# - `Terminated` — задача остановлена.
#
# Подробнее в [документации](https://cloud.ru/docs/aicloud/mlspace/concepts/client-lib__job#id4)

# %%
endpoint = f"jobs/{job_name}"

headers = {
    "x-api-key": credentials_dict["workspaces"][0]["x-api-key"],
    "authorization": auth_response_json["token"]["access_token"],
    "x-workspace-id": credentials_dict["workspaces"][0]["id"],
}

url = rest_call_template.format(host, endpoint)

response = requests.request("GET", url, headers=headers)

print(response.text)

# %% [markdown]
# ## Получение логи задачи ([содержание](#toc))<a class="anchor" id="jobs-logs"></a>
#
# Доступно после перехода задачи в статус "Выполняется(Running)"

# %%
endpoint = f"jobs/{job_name}/logs?region=SR004"

headers = {
    "x-api-key": credentials_dict["workspaces"][0]["x-api-key"],
    "authorization": auth_response_json["token"]["access_token"],
    "x-workspace-id": credentials_dict["workspaces"][0]["id"],
}

url = rest_call_template.format(host, endpoint)
JSON(job_response_json)

# %% [markdown]
# ## Остановка задачи ([содержание](#toc))<a class="anchor" id="jobs-delete"></a>
#
# Остановить задачу можно пока она находится в статусах `pending` или `running`

# %%
endpoint = f"jobs/{job_name}?region=SR004"

headers = {
    "x-api-key": credentials_dict["workspaces"][0]["x-api-key"],
    "authorization": auth_response_json["token"]["access_token"],
    "x-workspace-id": credentials_dict["workspaces"][0]["id"],
}

url = rest_call_template.format(host, endpoint)

response = requests.request("DELETE", url, headers=headers)

print(response.text)
